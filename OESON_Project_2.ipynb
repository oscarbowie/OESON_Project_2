# %% [markdown]
# <a href="https://colab.research.google.com/github/oscarbowie/OESON_Project_2/blob/main/OESON_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/content/HRDataset_v14.csv')

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %% [markdown]
# Descriptive Statistics

# %%
d = df.iloc[:,[9,29,30,31,33,34]]
sns.heatmap(d.corr(), cmap="YlGnBu", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Throughout most of the continuous data we see little relation. Relations of note include SpecialProjectsCount and Salary, EngagementSurvey and EmpSatisfaction, EngagementSurvey and DaysLateLast30, and, DaysLateLast30 and EmpSatisfaction.

# %%
fig, ax = plt.subplots(1,2,  figsize=(10, 5))
fig.tight_layout(pad=2)
fig.suptitle('Heatmap Plots', fontsize=20)
d = df[df['SpecialProjectsCount'] != 0]
sns.regplot(data=d, ax=ax[0], x='SpecialProjectsCount', y='Salary')
sns.regplot(data=df, ax=ax[1], x='EngagementSurvey', y='EmpSatisfaction')
# Out:
# <Axes: xlabel='EngagementSurvey', ylabel='EmpSatisfaction'>

# %% [markdown]
# While the many of the variables are discrete, we can say a little on the relationship between them, especially the postive relationship between Special Project Count and Salary, but also a slight positive relationship between Satisfaction and Engagement.

# %%
sns.countplot(data=df, x='GenderID')
# Out:
# <Axes: xlabel='GenderID', ylabel='count'>

# %%
fig, ax = plt.subplots(2,3, figsize=(10, 5))
fig.tight_layout(pad=2)
fig.suptitle('Distributions by Gender', fontsize=20)
group = 'GenderID'
sns.histplot(data=df, ax=ax[0,0], x='Salary', hue = group, kde='True')
sns.histplot(data=df, ax=ax[0,1], x='EngagementSurvey', hue = group, kde='True')
sns.histplot(data=df, ax=ax[0,2], x='EmpSatisfaction', hue = group, kde='True')
sns.histplot(data=df, ax=ax[1,0], x='SpecialProjectsCount', hue = group, kde='True')
sns.histplot(data=df, ax=ax[1,1], x='DaysLateLast30', hue = group, kde='True')
sns.histplot(data=df, ax=ax[1,2], x='Absences', hue = group, kde='True')
# Out:
# <Axes: xlabel='Absences', ylabel='Count'>

# %% [markdown]
# Little differences between the distribtions between the genders, of note, EmpSatisfaction and Absences differs a bit more between genders than the other metrics. Otherwise there is not much difference in the distributions between the genders. GenderID 1 line is less than GenderID 0 as there is less of GenderID = 0 overall as seen above.

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
fig.tight_layout(pad=2)
fig.suptitle('Gender and Performance', fontsize=20)
sns.countplot(data=df, ax=ax[0], x='GenderID', hue = 'PerformanceScore')

cross = pd.crosstab(index=df['GenderID'], columns=df['PerformanceScore'], normalize='index')
cross.plot(kind='bar', stacked='True', ax=ax[1])
plt.legend(loc="upper left")

# %% [markdown]
# We can see slight differences in the percentage performances between the genders, with a higher proportion of GenderID=0 having satisfactory or greater performance, where GenderID=1 has a slightly greater proportion of PIP and Needs Improvement performance percentages.

# %%
sns.countplot(data=df, x='MarriedID')
# Out:
# <Axes: xlabel='MarriedID', ylabel='count'>

# %%
fig, ax = plt.subplots(2,3, figsize=(10, 5))
fig.tight_layout(pad=2)
fig.suptitle('Distributions by Marital Status', fontsize=20)
group = 'MarriedID'
sns.histplot(data=df, ax=ax[0,0], x='Salary', hue = group, kde='True')
sns.histplot(data=df, ax=ax[0,1], x='EngagementSurvey', hue = group, kde='True')
sns.histplot(data=df, ax=ax[0,2], x='EmpSatisfaction', hue = group, kde='True')
sns.histplot(data=df, ax=ax[1,0], x='SpecialProjectsCount', hue = group, kde='True')
sns.histplot(data=df, ax=ax[1,1], x='DaysLateLast30', hue = group, kde='True')
sns.histplot(data=df, ax=ax[1,2], x='Absences', hue = group, kde='True')
# Out:
# <Axes: xlabel='Absences', ylabel='Count'>

# %% [markdown]
# MarriedID value also has little difference in its distributions, with distributions to note area again EmplSatisfaction and Absences, similar to GenderID.

# %%
df[df['DeptID']==2]
# Out:
#     Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  \
# 150   King, Janet  10089          1                1         0            1
#
#      DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 150       2            3                       0  250000  ...
#
#             ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 150  Board of Directors        9.0            Indeed      Fully Meets
#
#      EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 150              4.83               3                    0
#
#     LastPerformanceReview_Date DaysLateLast30 Absences
# 150                  1/17/2019              0       10
#
# [1 rows x 35 columns]

# %%
fig, ax = plt.subplots(1,3, figsize=(15,5))
fig.tight_layout(pad=2)
fig.suptitle('DeptID and Salary', fontsize=20)
sns.histplot(data=df, ax=ax[0], x=df['Salary']/1000, hue = 'DeptID', kde = 'True').set(xlabel = "Salary (1000s)")
d= df.groupby('DeptID').agg({'Salary':'mean'})
sns.barplot(data=d, ax=ax[1], x= d.index, y=d['Salary']/1000).set(ylabel = "Average Salary (1000s)")
sns.countplot(data=df, x='DeptID').set(ylabel ='Employee count')
# Out:
# [Text(970.81045751634, 0.5, 'Employee count')]

# %% [markdown]
# When looking at the differences in salary, we can see that DeptID 2 consists of 1 person, who is the Board of Directors, which explains the average salary of DeptID=2 being so large. Otherwise, there is not as larger distance in the rest of the Departments average salaries. We also notice that DeptID=5 contains the largest number of employees with the lowest average salary, likely a lower skill worker department, where something like DeptID 3 and 4 likely being more executive departments, as they contain less employees and are paid higher.

# %%
fig, ax = plt.subplots(1,2, figsize=(11,5))
fig.tight_layout(pad=2)
fig.suptitle('Salary and Performance', fontsize=20)
sns.histplot(data=df, ax=ax[0], x=df['Salary']/1000, hue = 'PerformanceScore', kde = 'True').set(xlabel = "Salary (1000s)")

d= df.groupby('PerformanceScore').agg({'Salary':'mean'})
sns.barplot(data=d, ax=ax[1], x= d.index, y=d['Salary']/1000).set(ylabel = "Salary (1000s)")
# Out:
# [Text(565.2222222222222, 0.5, 'Salary (1000s)')]

# %% [markdown]
# Evident that the salary appropriately aligns with performance, with a positive relationship, that as performance increases, salary increases on average.

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
fig.tight_layout(pad=2)
fig.suptitle('DeptID and Performance', fontsize=20)
sns.countplot(data=df, ax=ax[0], x='DeptID', hue = 'PerformanceScore')

cross = pd.crosstab(index=df['DeptID'], columns=df['PerformanceScore'], normalize='index')
cross.plot(kind='bar', stacked='True', ax=ax[1])
plt.legend(loc="upper left")

# %% [markdown]
# Departments with the highest levels of unsatisfactory performance are DeptID's 6, 5, and 4, with department 3 having less unsatisfactory performance, and DeptID's 1,2 containing no unsatisfactory performance, however these departments are also much smaller.

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
fig.tight_layout(pad=2)
fig.suptitle('Performance Score and Absences', fontsize=20)
sns.histplot(data=df, ax=ax[0], x=df['Absences'], hue = 'PerformanceScore', kde = 'True').set(xlabel = "Absences")
d= df.groupby('PerformanceScore').agg({'Absences':'mean'})
sns.barplot(data=d, ax=ax[1], x= d.index, y=d['Absences']).set(ylabel = "Average Absences")
# Out:
# [Text(510.4494949494949, 0.5, 'Average Absences')]

# %% [markdown]
# Little differences between the average absences and performance levels, however it can be noted that the satisfactory performances have on average less average absences than those that "Need Improvement".

# %%
def yesNo(string):
  if string.lower() == 'yes':
    return 1
  else: return 0

# %%
d = df
d['HispanicLatino']=d['HispanicLatino'].apply(yesNo)

# %%
fig, ax = plt.subplots(1,3, figsize=(13,5))
fig.tight_layout(pad=2)


fig.suptitle('Salary and Hispanic Latino Ethicity', fontsize=20)
sns.histplot(data=d, ax=ax[0], x=df['Salary']/1000, hue = 'HispanicLatino', kde = 'True').set(xlabel = "Salary (1000s)")

f= df.groupby('HispanicLatino').agg({'Salary':'mean'})
sns.barplot(data=f, ax=ax[1], x= f.index, y=f['Salary']/1000).set(ylabel = "Salary (1000s)")

sns.countplot(data=d, ax=ax[2], x='HispanicLatino').set(ylabel ='Employee count')
# Out:
# [Text(836.3986928104576, 0.5, 'Employee count')]

# %% [markdown]
# Also found little difference between the distributions of salaries between HispanicLatino and non-HispanicLatino groups, with HispanicLatino "yes" having a slightly higher average salary, but also having many less employees who indentify such way.
